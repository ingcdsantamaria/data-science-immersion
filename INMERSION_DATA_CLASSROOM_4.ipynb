# %% [markdown]
# Bienvenido a nuestro primer encuentro de inmersion de datos.

# %% [markdown]
# ---
# # **CLASSROOM 1**
# ---

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

inmuebles = pd.read_csv('/content/drive/MyDrive/inmersion data science/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {'Baños' : 'Banos', 'Área' : 'Area'}
inmuebles = inmuebles.rename(columns = columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 1399  Apartamento           Apartamento en venta en Chapinero             3
# 9413  Apartamento             Apartamento en venta en Kennedy             2
# 4901  Apartamento      Apartamento en venta en Barrios Unidos             3
# 8326  Apartamento           Apartamento en venta en San Diego             1
# 6503  Apartamento             Apartamento en venta en Usaquén             2
# 8566  Apartamento             Apartamento en venta en Usaquén             2
# 6867  Apartamento            Apartamento en venta en Cedritos             3
# 4251  Apartamento           Apartamento en venta en Chapinero             3
# 5985  Apartamento     Apartamento en venta en Chico Reservado             3
# 6423  Apartamento  Apartamento en venta en Zona Noroccidental             3
#
#       Banos  Area              Barrio                                     UPZ  \
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
inmuebles['Valor'][300:305]
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# Name: Valor, dtype: object

# %%
type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.sample(100)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 7674  Apartamento       Apartamento en venta en Engativa             3      1
# 7493         Casa              Casa en venta en Fontibón             2      1
# 1078  Apartamento      Apartamento en venta en Chapinero             2      2
# 8987  Apartamento        Apartamento en venta en Usaquén             4      5
# 3556         Casa              Casa en venta en El Batán             7      4
# ...           ...                                    ...           ...    ...
# 280   Apartamento        Apartamento en venta en Usaquén             3      3
# 1547         Casa    Casa en venta en Zona Noroccidental             6      3
# 5887  Apartamento  Apartamento en venta en Santa Barbara             2      2
# 7534  Apartamento    Apartamento en venta en Teusaquillo             3      3
# 7482         Casa         Casa en venta en Puente Aranda            10      6
#
# ...

# %%
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
inmuebles.UPZ.value_counts()
# Out:
# Usaquén                                  1681
# CHAPINERO: Pardo Rubio + Chapinero       1274
# USAQUÉN: Country Club + Santa Bárbara     771
# Bosa Central                              591
# Kennedy Central                           589
#                                          ...
# Localidad Usme resto                        2
# Las Cruces                                  2
# La Macarena                                 1
# Fontibón San Pablo                          1
# Zona Franca                                 1
# Name: UPZ, Length: 63, dtype: int64

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# **DESAFIAO**
#
#
# 1.   Calcular el promedio de area de todos los inmuebles en los barrios en el dataset y mostrar el Top 10
#
#
# ---

# %% [markdown]
# **SOLUCION**

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles_area = inmuebles.groupby('Barrio')['Area'].mean()
inmuebles_area
# Out:
# Barrio
# Alameda                97.000000
# Alhambra              190.411765
# Andes Norte           124.857143
# Antonio Nariño        163.062500
# Barrancas              70.200000
#                          ...
# Villa Maria           207.153846
# Villas De Granada      86.590909
# Villemar               76.888889
# Zona Franca            54.000000
# Zona Noroccidental    135.785633
# Name: Area, Length: 149, dtype: float64

# %%
inmuebles_area.sort_values(ascending=False)
# Out:
# Barrio
# Modelia            4316.750000
# Libertador          642.000000
# Bosa Piamonte       400.000000
# La Soledad          378.625000
# Restrepo            336.500000
#                       ...
# La Merced            41.000000
# El Tunal             41.000000
# San Diego            40.666667
# La Macarena          37.000000
# Prado Veraniego      25.000000
# Name: Area, Length: 149, dtype: float64

# %%
inmuebles_area.sort_values(ascending=False).head(10)
# Out:
# Barrio
# Modelia                  4316.750000
# Libertador                642.000000
# Bosa Piamonte             400.000000
# La Soledad                378.625000
# Restrepo                  336.500000
# Santa Librada             328.000000
# Las Ferias                320.000000
# Santa Ana                 309.375000
# Veraguas                  302.666667
# Bellavista Occidental     286.200000
# Name: Area, dtype: float64

# %%
graficoTopAreaBarrios = inmuebles_area.sort_values(ascending=False).head(10).plot.bar()

# %% [markdown]
# 2.   consultar otros datos estadisticos, conteo, mediana, valores minimos y maximo.
#
#
#
# ---

# %% [markdown]
# **SOLUCION**
#
# Algunos de los que encontramos son estos:
#
# 1.   count(): cuenta el número de elementos en un DataFrame.
# 2. mean(): calcula la media de los elementos en un DataFrame.
# 3. median(): calcula la mediana de los elementos en un DataFrame.
# 4. min(): encuentra el valor mínimo en un DataFrame.
# 5. max(): encuentra el valor máximo en un DataFrame.
# 6. sum(): calcula la suma de los elementos en un DataFrame.
# 7. std(): calcula la desviación estándar de los elementos en un DataFrame.
# 8. var(): calcula la varianza de los elementos en un DataFrame.
# 9. quantile(): calcula el percentil de los elementos en un DataFrame.
# 10. describe(): calcula varias estadísticas resumidas sobre un DataFrame.
# 11. corr(): calcula la correlación entre columnas en un DataFrame.
# 12. cov(): calcula la covarianza entre columnas en un DataFrame.
# 13. skew(): calcula el sesgo de los elementos en un DataFrame.
# 14. kurtosis(): calcula la curtosis de los elementos en un DataFrame.
# 15. cumsum(): calcula la suma acumulativa de los elementos en un DataFrame.

# %% [markdown]
# **Ejemplo de cada algunas de esta funcion con nuestra dataframe**

# %% [markdown]
# 1.   En este caso queremos saber el numero de barrios en la localidad de bogota con el fin de saber nuestra poblacion.

# %%
inmuebles_barrio.count()
# Out:
# 149

# %% [markdown]
# 2.   En este caso vamos a sacar el promedio del area de los inmuebles con el fin de analizar un tamaño en metros cuadrados

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# 3. calculamos la mediana con el fin de conocer la cantidad de baños promedio que tienen los inmuebles en una determinada zona o barrio.

# %%
int(round(inmuebles.Banos.median()))
# Out:
# 2

# %% [markdown]
# 4. calculamos el valor minimo de los inmubles y lo mostramos con el fin de conocer su ubicacion y valor para posibles compras

# %%
inmuebles.loc[inmuebles['Valor'] == inmuebles.Valor.min()].head(3)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 911          Casa          Casa en venta en San Patricio             3      3
# 1138  Apartamento  Apartamento en venta en San Cristobal             4      5
# 1735  Apartamento     Apartamento en venta en Bogotá D.C             3      3
#
#       Area         Barrio                                    UPZ  \
# 911    178   San Patricio  USAQUÉN: Country Club + Santa Bárbara
# 1138   231  San Cristobal                                Sosiego
# 1735   183     Bogotá D.C              Ciudad Salitre Occidental
#
#                 Valor
# 911   $ 1.000.000.000
# 1138  $ 1.000.000.000
# 1735  $ 1.000.000.000

# %% [markdown]
# 5. Se presenta el valor maximo de habitaciones con el fin de tener un presupuesto para y informacion para su adquisicion y cumplimiento de requerimientos del mismo

# %%
inmuebles.loc[inmuebles['Habitaciones'] == inmuebles.Habitaciones.max()]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor
# 897  Usaquén  $ 480.000.000

# %% [markdown]
# 6. nos solicitan saber la cantidad de los inmuebles en cierta localidad

# %%
sum(inmuebles.Barrio == 'Kennedy')
# Out:
# 589

# %% [markdown]
# 7. calculamos la desviacion estandar con el fin de indicar cuánto varían los tamaños de los inmuebles.

# %%
inmuebles.Area.std()
# Out:
# 1731.3796224307055

# %% [markdown]
# 8. calculamos la varianza de los baños con el fin de entender mejor la distribucion de los datos

# %%
int(round(inmuebles.Banos.var()))
# Out:
# 2

# %% [markdown]
# 9. calculamos el percentil de las habitaciones con el fin de indicar cuantas habitaciones tienen las propiedades que se encuentran en el cuartil superior(esto significa que el 75% de las propiedades tienen 3 habitaciones o menos, mientras que el 25% restante tiene más de 3 habitaciones.)

# %%
inmuebles['Habitaciones'].quantile(0.75)
# Out:
# 3.0

# %% [markdown]
# 10. utilizamos la funcion describe() con el fin de obtener un resumen estadístico de un conjunto de datos

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area
# count   9520.000000  9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706
# std        2.049856     1.255314    1731.379622
# min        1.000000     0.000000       2.000000
# 25%        2.000000     2.000000      57.000000
# 50%        3.000000     2.000000      80.000000
# 75%        3.000000     3.000000     135.000000
# max      110.000000     9.000000  166243.000000

# %% [markdown]
# 11. calculamos la correlacion para indicar el grado en que dos variables están relacionadas entre sí. Un valor de correlación cercano a 1 indica una relación positiva fuerte, un valor cercano a -1 indica una relación negativa fuerte, y un valor cercano a 0 indica una falta de relación entre las variables.

# %%
inmuebles.corr()
# Out:
#               Habitaciones     Banos      Area
# Habitaciones      1.000000  0.484762  0.038070
# Banos             0.484762  1.000000  0.059479
# Area              0.038070  0.059479  1.000000

# %% [markdown]
# 12. Calculamos la cobarianza con el fin de indica la dirección de la relación entre dos variables. Un valor de covarianza positivo indica que las variables tienden a moverse en la misma dirección, mientras que un valor negativo indica que tienden a moverse en direcciones opuestas.

# %%
inmuebles.cov()
# Out:
#               Habitaciones       Banos          Area
# Habitaciones      4.201911    1.247395  1.351138e+02
# Banos             1.247395    1.575812  1.292742e+02
# Area            135.113810  129.274156  2.997675e+06

# %% [markdown]
# ---
# # **CLASSROOM 2**
#
# ---

# %%
inmuebles.sample(5)
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 6458  Apartamento  Apartamento en venta en Chico Reservado             3
# 155   Apartamento         Apartamento en venta en Cedritos             4
# 1950         Casa             Casa en venta en Teusaquillo            14
# 8053         Casa                 Casa en venta en Usaquén             3
# 6476  Apartamento         Apartamento en venta en Cedritos             1
#
#       Banos  Area           Barrio                                 UPZ  \
# 6458      4   152  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 155       3   135         Cedritos                             Usaquén
# 1950      4   325      Teusaquillo                         Teusaquillo
# 8053      3   240          Usaquén                             Usaquén
# 6476      2    51         Cedritos                             Usaquén
#
#                 Valor
# 6458    $ 995.000.000
# 155     $ 635.000.000
# 1950  $ 1.580.000.000
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# *   tipo de dato de valor es str

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %% [markdown]
# *   al sumar 2 string los concatena

# %%
inmuebles.Valor[0]+inmuebles.Valor[1]+inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000$ 670.000.000$ 360.000.000
# 1      $ 360.000.000$ 670.000.000$ 670.000.000
# 2    $ 360.000.000$ 670.000.000$ 1.120.000.000
# 3      $ 360.000.000$ 670.000.000$ 890.000.000
# 4      $ 360.000.000$ 670.000.000$ 970.000.000
# Name: Valor, dtype: object

# %% [markdown]
# *   Aplicacion de funciones de string para tratar datos

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %% [markdown]
# *   aplicacion a toda la columna (expand es para volver en formato de dataframe)

# %%
valor = inmuebles.Valor.str.split(expand=True)
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1]
inmuebles.sample(3)
# Out:
#              Tipo                       Descripcion  Habitaciones  Banos  \
# 779   Apartamento   Apartamento en venta en Usaquén             1      2
# 5816  Apartamento   Apartamento en venta en Kennedy             3      2
# 7736  Apartamento  Apartamento en venta en Cedritos             2      2
#
#       Area    Barrio              UPZ          Valor Moneda       Precio
# 779     54   Usaquén          Usaquén  $ 400.000.000      $  400.000.000
# 5816    70   Kennedy  Kennedy Central  $ 350.000.000      $  350.000.000
# 7736    79  Cedritos          Usaquén  $ 330.000.000      $  330.000.000

# %% [markdown]
# *   informacion de los datos para verificar si se actualizo la modificacion

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %% [markdown]
# *
# trataremos los datos eliminaremos los puntos
# *     **NOTA:** Es importante el tratamiento de datos para su manipulacion

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','',regex=True)

# %%
inmuebles[['Precio','Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %% [markdown]
# max y min forma rapida con la funcion describe

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %% [markdown]
# lo utilizamos para dejar solo 2 decimales en una funcion lambda

# %%
pd.set_option('display.precision',2)
pd.set_option('display.float_format',lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %%
inmuebles['Precio_Millon'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# importaremos herramientas de python para ver mejor ese tipo de graficos

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))


grafica = sns.histplot(data=inmuebles, x = 'Precio_Millon', kde = True, hue='Tipo')

grafica.set_title('Distribucion de valores de los inmuebles en bogota')

plt.xlim((50,1000))


plt.savefig('/content/drive/MyDrive/inmersion data science/valor_inmuebles.png',format='png')

plt.show()

# %% [markdown]
# **DESAFIO**
#
#
#
# 1.   Estudiar mejor el histograma de valores seleccionar 3 tipos de inmuebles(refinar el grafico: Titulos, aumentar el tamaño de labels, conclusion de la informacion)

# %%
plt.figure(figsize=(10,6))


tipos_seleccionados = ['Local', 'Bodega', 'Lote']
inmuebles_seleccionados = inmuebles[inmuebles['Tipo'].isin(tipos_seleccionados)]

grafica = sns.histplot(data=inmuebles_seleccionados, x='Precio_Millon', kde=True, hue='Tipo')
grafica.set_title('Distribucion de valores de 3 inmuebles', fontsize=18)
grafica.set_xlabel('Precio (en millones)', fontsize=16)
grafica.set_ylabel('Cantidad', fontsize=16)

plt.xlim((50,6000))

plt.savefig('/content/drive/MyDrive/inmersion data science/valor_3_inmuebles.png',format='png')
plt.show()

# %% [markdown]
# **CONCLUSIONES:**
#
# 1.   Basandonos en la altura de las barras de color azul(Locales), esta claro que la cantidad de locales en venta es mayor a la de bodegas y lotes sin embargo evidenciamos que los que se encuentran con un valor entre 100 millones a 600 millones quien supera la cantidad de inmuebles en venta son las bodegas.
# 2.   Basandonos en la altura de las barras de colo verde(Lote), esta claro que tiene las ventas mas bajas y los valores mas economicos esto con el fin de visualizar posibles compras

# %% [markdown]
# 2.   Precio del m2 por barrio y investigar que grafica se adecue mas para esta nueva variable y hacer el grafico mas adecuado para esta nueva variable(precio del metro cuadrado es igual a precio/m2=precioMetroCuadrado)

# %%
inmuebles['valor_metroCuadrado'] = inmuebles.Precio_Millon / inmuebles.Area

plt.figure(figsize=(10,6))

grafica = sns.scatterplot(data=inmuebles, x = 'valor_metroCuadrado',y = 'Precio_Millon', hue='Tipo')

grafica.set_title('Distribucion de valor de metro cuadrado por valor total', fontsize=18)
grafica.set_xlabel('Valor por metro cuadrado (en millones)', fontsize=16)
grafica.set_ylabel('Valor total', fontsize=16)

plt.savefig('/content/drive/MyDrive/inmersion data science/valor_metro_cuadrado.png',format='png')
plt.xlim((5,95))

plt.show()

# %% [markdown]
# **Conclusiones:** basando nos en el grafico de dispercion evidenciamos varios inmuebles sobrevalorados o subvalorados en relación con su valor por metro cuadrado y su valor total, por lo que se debe encontrar en que area de la empresa se presento este error de digitacion o de type.

# %% [markdown]
# ---
#
# # **CLASSROOM 3**
# ---

# %%
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  valor_metroCuadrado  \
# 0    $ 360.000.000      $   360000000         360.00                 5.14
# 1    $ 670.000.000      $   670000000         670.00                 3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00                 7.78
#
#    valor_m2_Barrio
# 0             4.57
# 1             3.40
# 2             8.10

# %% [markdown]
# resolviendo ejercicio clase anterior

# %%
inmuebles.groupby('Barrio').mean()
# Out:
#                     Habitaciones  Banos   Area  Precio_Millon  \
# Barrio
# Alameda                     3.00   2.00  97.00         580.00
# Alhambra                    3.00   2.94 190.41         752.35
# Andes Norte                 3.00   2.86 124.86         709.57
# Antonio Nariño              4.31   2.50 163.06         459.22
# Barrancas                   2.87   2.13  70.20         314.13
# ...                          ...    ...    ...            ...
# Villa Maria                 4.69   3.69 207.15         402.85
# Villas De Granada           3.45   2.32  86.59         282.30
# Villemar                    2.94   2.06  76.89         303.83
# Zona Franca                 2.00   1.00  54.00         160.00
# Zona Noroccidental          3.17   2.51 135.79         620.81
#
#                     valor_metroCuadrado
# Barrio
# Alameda                            5.98
# Alhambra                           4.33
# Andes Norte                        6.05
# ...

# %%
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     valor_metroCuadrado
# Barrio
# Alameda                            5.98
# Alhambra                          73.56
# Andes Norte                       42.35
# ...

# %%
datos_barrio['valor_m2_Barrio'] = datos_barrio['Precio_Millon']/datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     valor_metroCuadrado  valor_m2_Barrio
# Barrio
# Alameda                            5.98             5.98
# Alhambra                          73.56             3.95
# ...

# %%
m2_barrio = dict(datos_barrio['valor_m2_Barrio'])

# %%
inmuebles['valor_m2_Barrio'] = inmuebles['Barrio']
inmuebles['valor_m2_Barrio'] = inmuebles['valor_m2_Barrio'].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  valor_metroCuadrado  \
# ...

# %% [markdown]
# top 10 de barrios

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      valor_metroCuadrado  valor_m2_Barrio
# 0                   5.98             5.98
# 1                  73.56             3.95
# ...

# %% [markdown]
# query se puede utilizar para consultas y la @es para hacer referencia a la variable

# %%
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      valor_metroCuadrado  valor_m2_Barrio
# 5                2070.61             2.96
# 10               1654.36             2.68
# 22               2853.23             5.03
# 24               2466.03             4.58
# ...

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x='Barrio', y='valor_m2_Barrio',data=datos_barrio.query('Barrio in @top_barrios'))

ax.tick_params(axis='x', rotation=45)

# %% [markdown]
# descripcion estadistica boxplot

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='valor_metroCuadrado',data=inmuebles.query('Barrio in @top_barrios'))

ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# expandir

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='valor_metroCuadrado',data=inmuebles.query('Barrio in @top_barrios & valor_metroCuadrado < 15'))

ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# aut layer son los punticos del grafico de cajas son datos que pueden ser erroneos

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Area',data=inmuebles.query('Barrio in @top_barrios & Area < 500'))

ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Precio_Millon',data=inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))

ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Vamos a traer datos estadísticos de la ciudad de Bogotá, directamente del DANE y vamos a ver como estos datos nos ayudarían en inclusión de nuevas variables para el cálculo del precio de los inmuebles en la ciudad de Bogotá.
#
# Encuesta Multiproposito de Bogotá para obtener información socio-económica y de entorno urbano de los habitantes de Bogotá para la formulación, seguimiento y evaluación de las políticas distritales.
#
# https://microdatos.dane.gov.co/index.php/catalog/743

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/inmersion data science/Identificación (Capítulo A).csv', sep=';',encoding='latin-1')
datos_raw.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# ...

# %%
datos_raw.shape
# Out:
# (106467, 11)

# %%
datos_raw = datos_raw.loc[datos_raw.MPIO == 11001]
datos_raw.shape
# Out:
# (86504, 11)

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/inmersion data science/Datos de la vivenda y su entorno (Capítulo B).csv',sep=';',encoding='latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/inmersion data science/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/inmersion data science/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/inmersion data science/Educación (Capítulo H).csv',sep=';',encoding='latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/inmersion data science/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv',sep=';',encoding='latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/inmersion data science/Fuerza de trabajo (Capítulo K).csv',sep=';',encoding='latin-1')
# Out:
# <ipython-input-97-3d106255da3c>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/inmersion data science/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
# <ipython-input-97-3d106255da3c>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/inmersion data science/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
# <ipython-input-97-3d106255da3c>:4: DtypeWarning: Columns (81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/inmersion data science/Educación (Capítulo H).csv',sep=';',encoding='latin-1')
# ...

# %%
datos_dane = pd.merge(datos_raw,datos_b,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_raw,datos_c,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 152)

# %%
datos_dane = pd.merge(datos_raw,datos_e,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (235103, 78)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 235103 entries, 0 to 235102
# Data columns (total 78 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   DIRECTORIO        235103 non-null  float64
#  1   DPTO              235103 non-null  int64
#  2   MPIO              235103 non-null  int64
#  3   CLASE             235103 non-null  int64
#  4   COD_LOCALIDAD     235103 non-null  float64
#  5   NOMBRE_LOCALIDAD  235103 non-null  object
#  6   COD_UPZ_GRUPO     226740 non-null  float64
#  7   NOMBRE_UPZ_GRUPO  226740 non-null  object
#  8   ESTRATO2021       235103 non-null  int64
#  9   NOMBRE_ESTRATO    235103 non-null  object
#  10  FEX_C_x           235103 non-null  object
#  11  DIRECTORIO_HOG    235103 non-null  int64
#  12  DIRECTORIO_PER    235103 non-null  int64
#  13  SECUENCIA_P       235103 non-null  int64
#  14  ORDEN             235103 non-null  int64
#  15  NPCEP4            235103 non-null  int64
# ...

# %% [markdown]
# **DESAFIOS:**
#
#
# 1.   Dar un vistazo a la base de datos de DANE, entender estas veriables, conceptual para entender mejor el contexto de esta base.
# 2.   Organizar tu notebook para que tu proyecto quede mejor presentado.

# %% [markdown]
# ---
#
#
# # **CLASSROOM 4**
#
#
# ---

# %%
datos_dane = pd.read_csv('/content/drive/MyDrive/inmersion data science/datos_dane.csv')
datos_dane.head()
# Out:
#    DIRECTORIO NOMBRE_LOCALIDAD                                 NOMBRE_ESTRATO  \
# 0  3004368.00          Usaquén  USAQUÉN: Paseo de Los Libertadores + La Uribe
# 1  3004369.00          Usaquén                                        Usaquén
# 2  3004375.00        Chapinero             CHAPINERO: Pardo Rubio + Chapinero
# 3  3004380.00          Usaquén                                     Los Cedros
# 4  3004383.00         Fontibón                      Ciudad Salitre Occidental
#
#    NVCBP4  NVCBP14A  NVCBP14D  NVCBP14E  NVCBP14G  NVCBP15A  NVCBP15C  ...  \
# 0       1         2         2         2         2         2         2  ...
# 1       1         2         2         2         2         2         2  ...
# 2       2         2         2         2         2         2         1  ...
# 3       1         2         2         2         2         2         2  ...
# 4       1         2         2         2         2         1         2  ...
#
# ...

# %%
datos_dane.shape
# Out:
# (9857, 55)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DIRECTORIO        9857 non-null   float64
#  1   NOMBRE_LOCALIDAD  9857 non-null   object
#  2   NOMBRE_ESTRATO    9857 non-null   object
#  3   NVCBP4            9857 non-null   int64
#  4   NVCBP14A          9857 non-null   int64
#  5   NVCBP14D          9857 non-null   int64
#  6   NVCBP14E          9857 non-null   int64
#  7   NVCBP14G          9857 non-null   int64
#  8   NVCBP15A          9857 non-null   int64
#  9   NVCBP15C          9857 non-null   int64
#  10  NVCBP15F          9857 non-null   int64
#  11  NVCBP15G          9857 non-null   int64
#  12  NVCBP16A3         9857 non-null   int64
#  13  NVCBP16A4         9857 non-null   int64
#  14  NPCKP17           9857 non-null   float64
#  15  NPCKP18           9857 non-null   float64
# ...

# %%
dic_dane = {
       'NVCBP4':'CONJUNTO_CERRADO',
       'NVCBP14A':'FABRICAS_CERCA', 'NVCBP14D':'TERMINALES_BUS', 'NVCBP14E':'BARES_DISCO', 
       'NVCBP14G':'OSCURO_PELIGROSO', 'NVCBP15A':'RUIDO', 'NVCBP15C':'INSEGURIDAD',
       'NVCBP15F':'BASURA_INADECUADA', 'NVCBP15G':'INVASION','NVCBP16A3':'MOV_ADULTOS_MAYORES', 
       'NVCBP16A4':'MOV_NINOS_BEBES',
       'NPCKP17':'OCUPACION','NPCKP18':'CONTRATO','NPCKP23':'SALARIO_MES', 
       'NPCKP44A':'DONDE_TRABAJA', 'NPCKPN62A':'DECLARACION_RENTA', 
       'NPCKPN62B':'VALOR_DECLARACION', 'NPCKP64A':'PERDIDA_TRABAJO_C19', 
       'NPCKP64E':'PERDIDA_INGRESOS_C19',
       'NHCCP3':'TIENE_ESCRITURA', 'NHCCP6':'ANO_COMPRA', 'NHCCP7':'VALOR_COMPRA', 'NHCCP8_1':'HIPOTECA_CRED_BANCO',
       'NHCCP8_2':'OTRO_CRED_BANCO', 'NHCCP8_3':'CRED_FNA', 'NHCCP8_6':'PRESTAMOS_AMIGOS',
       'NHCCP8_7':'CESANTIAS', 'NHCCP8_8':'AHORROS', 'NHCCP8_9':'SUBSIDIOS',
       'NHCCP9':'CUANTO_PAGARIA_MENSUAL', 'NHCCP11':'PLANES_ADQUIRIR_VIVIENDA', 
       'NHCCP11A':'MOTIVO_COMPRA', 'NHCCP12':'RAZON_NO_ADQ_VIV', 'NHCCP41':'TIENE_CARRO','NHCCP41A':'CUANTOS_CARROS',
       'NHCCP47A':'TIENE_PERROS', 'NHCCP47B':'TIENE_GATOS', 'NHCLP2A':'VICTIMA_ATRACO', 'NHCLP2B':'VICTIMA_HOMICIDIO', 
       'NHCLP2C':'VICTIMA_PERSECUSION',
       'NHCLP2E':'VICTIMA_ACOSO', 'NHCLP4':'COMO_VIVE_ECON', 'NHCLP5':'COMO_NIVEL_VIDA', 
       'NHCLP8AB':'REACCION_OPORTUNA_POLICIA', 'NHCLP8AE':'COMO_TRANSPORTE_URBANO', 'NHCLP10':'SON_INGRESOS_SUFICIENTES',
       'NHCLP11':'SE_CONSIDERA_POBRE', 'NHCLP29_1A':'MED_C19_TRABAJO', 
       'NHCLP29_1C':'MED_C19_CAMBIO_VIVIENDA', 'NHCLP29_1E':'MED_C19_ENDEUDAMIENTO', 
       'NHCLP29_1F':'MED_C19_VENTA_BIENES','NPCHP4':'NIVEL_EDUCATIVO'
       }

datos_dane = datos_dane.rename(columns=dic_dane)
datos_dane.columns
# Out:
# Index(['DIRECTORIO', 'NOMBRE_LOCALIDAD', 'NOMBRE_ESTRATO', 'CONJUNTO_CERRADO',
#        'FABRICAS_CERCA', 'TERMINALES_BUS', 'BARES_DISCO', 'OSCURO_PELIGROSO',
#        'RUIDO', 'INSEGURIDAD', 'BASURA_INADECUADA', 'INVASION',
#        'MOV_ADULTOS_MAYORES', 'MOV_NINOS_BEBES', 'OCUPACION', 'CONTRATO',
#        'SALARIO_MES', 'DONDE_TRABAJA', 'DECLARACION_RENTA',
#        'VALOR_DECLARACION', 'PERDIDA_TRABAJO_C19', 'PERDIDA_INGRESOS_C19',
#        'TIENE_ESCRITURA', 'ANO_COMPRA', 'VALOR_COMPRA', 'HIPOTECA_CRED_BANCO',
#        'OTRO_CRED_BANCO', 'CRED_FNA', 'PRESTAMOS_AMIGOS', 'CESANTIAS',
#        'AHORROS', 'SUBSIDIOS', 'CUANTO_PAGARIA_MENSUAL',
#        'PLANES_ADQUIRIR_VIVIENDA', 'MOTIVO_COMPRA', 'RAZON_NO_ADQ_VIV',
#        'TIENE_CARRO', 'CUANTOS_CARROS', 'TIENE_PERROS', 'TIENE_GATOS',
#        'VICTIMA_ATRACO', 'VICTIMA_HOMICIDIO', 'VICTIMA_PERSECUSION',
#        'VICTIMA_ACOSO', 'COMO_VIVE_ECON', 'COMO_NIVEL_VIDA',
#        'REACCION_OPORTUNA_POLICIA', 'COMO_TRANSPORTE_URBANO',
# ...

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DIRECTORIO                 9857 non-null   float64
#  1   NOMBRE_LOCALIDAD           9857 non-null   object
#  2   NOMBRE_ESTRATO             9857 non-null   object
#  3   CONJUNTO_CERRADO           9857 non-null   int64
#  4   FABRICAS_CERCA             9857 non-null   int64
#  5   TERMINALES_BUS             9857 non-null   int64
#  6   BARES_DISCO                9857 non-null   int64
#  7   OSCURO_PELIGROSO           9857 non-null   int64
#  8   RUIDO                      9857 non-null   int64
#  9   INSEGURIDAD                9857 non-null   int64
#  10  BASURA_INADECUADA          9857 non-null   int64
#  11  INVASION                   9857 non-null   int64
#  12  MOV_ADULTOS_MAYORES        9857 non-null   int64
# ...

# %%
datos_dane.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean().head()
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   1.89
# Américas                                                      1.38
# Apogeo                                                        1.65
# Arborizadora                                                  1.43
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              1.37
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# 20 de Julio                                              1.19            1.85
# Américas                                                 1.25            1.98
# Apogeo                                                   1.30            1.75
# Arborizadora                                             1.30            1.95
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre         1.33            1.99
#
# ...

# %%
datos = datos_dane[['NOMBRE_ESTRATO','CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].replace(2,0)
datos
# Out:
#                                      NOMBRE_ESTRATO  CONJUNTO_CERRADO  \
# 0     USAQUÉN: Paseo de Los Libertadores + La Uribe                 1
# 1                                           Usaquén                 1
# 2                CHAPINERO: Pardo Rubio + Chapinero                 0
# 3                                        Los Cedros                 1
# 4                         Ciudad Salitre Occidental                 1
# ...                                             ...               ...
# 9852         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9853         SANTA FE: Las Nieves + Sagrado Corazón                 0
# 9854         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9855         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9856                                   Santa Isabel                 0
#
#       INSEGURIDAD  TERMINALES_BUS  BARES_DISCO  RUIDO  OSCURO_PELIGROSO  \
# ...

# %%
datos.NOMBRE_ESTRATO.value_counts()
# Out:
# Niza                                                   243
# SUBA: La Academia + Guaymaral + San José de Bavaria    212
# CHAPINERO: Chicó Lago + El Refugio                     210
# Los Libertadores                                       208
# Modelia                                                205
#                                                       ...
# Tunjuelito                                              26
# Lourdes                                                 25
# Localidad Chapinero resto                               21
# Localidad Usaquén resto                                 10
# Localidad Santa Fe resto                                 8
# Name: NOMBRE_ESTRATO, Length: 102, dtype: int64

# %%
datos.loc[datos.NOMBRE_ESTRATO == '20 de Julio']
# Out:
#      NOMBRE_ESTRATO  CONJUNTO_CERRADO  INSEGURIDAD  TERMINALES_BUS  \
# 513     20 de Julio                 0            0               0
# 706     20 de Julio                 0            1               0
# 707     20 de Julio                 0            1               0
# 708     20 de Julio                 0            1               0
# 709     20 de Julio                 0            1               0
# ...             ...               ...          ...             ...
# 8372    20 de Julio                 0            1               0
# 8751    20 de Julio                 0            0               0
# 8752    20 de Julio                 0            1               0
# 8783    20 de Julio                 0            1               1
# 9287    20 de Julio                 0            1               0
#
#       BARES_DISCO  RUIDO  OSCURO_PELIGROSO  SALARIO_MES  TIENE_ESCRITURA  \
# 513             0      1                 0        98.00             1.00
# ...

# %%
datos.loc[datos.NOMBRE_ESTRATO == 0]
# Out:
# Empty DataFrame
# Columns: [NOMBRE_ESTRATO, CONJUNTO_CERRADO, INSEGURIDAD, TERMINALES_BUS, BARES_DISCO, RUIDO, OSCURO_PELIGROSO, SALARIO_MES, TIENE_ESCRITURA, PERDIDA_TRABAJO_C19, PERDIDA_INGRESOS_C19, PLANES_ADQUIRIR_VIVIENDA]
# Index: []

# %%
datos_tratados = datos.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean()
datos_tratados
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   0.11
# Américas                                                      0.62
# Apogeo                                                        0.35
# Arborizadora                                                  0.57
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              0.63
# ...                                                            ...
# Usaquén                                                       0.90
# Venecia                                                       0.47
# Verbenal                                                      0.77
# Zona Franca                                                   0.94
# Álamos                                                        0.65
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# ...

# %%
pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
datos_ml = pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9520 entries, 0 to 9519
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9520 non-null   object
#  1   Descripcion               9520 non-null   object
#  2   Habitaciones              9520 non-null   int64
#  3   Banos                     9520 non-null   int64
#  4   Area                      9520 non-null   int64
#  5   Barrio                    9520 non-null   object
#  6   UPZ                       9478 non-null   object
#  7   Valor                     9520 non-null   object
#  8   Moneda                    9520 non-null   object
#  9   Precio                    9520 non-null   object
#  10  Precio_Millon             9520 non-null   float64
#  11  valor_metroCuadrado       9520 non-null   float64
#  12  valor_m2_Barrio           9520 non-null   float64
# ...

# %%
upz = pd.read_csv('/content/drive/MyDrive/inmersion data science/cod_upz.csv')
upz.head()
# Out:
#                            NOMBRE_ESTRATO  COD_UPZ_GRUPO
# 0  SANTA FE: Las Nieves + Sagrado Corazón         814.00
# 1                            Santa Isabel          37.00
# 2   USAQUÉN: Country Club + Santa Bárbara         803.00
# 3      CHAPINERO: Pardo Rubio + Chapinero         816.00
# 4               Ciudad Salitre Occidental         110.00

# %%
datos_ml = pd.merge(datos_ml,upz,left_on='UPZ',right_on='NOMBRE_ESTRATO',how='inner')
datos_ml.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                      Casa en venta en Marly             3
# 2         Casa         Casa en venta en Zona Noroccidental             3
# 3  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4         Casa         Casa en venta en Zona Noroccidental             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   147               Marly  CHAPINERO: Pardo Rubio + Chapinero
# 2      4   300  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 3      1    45  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 4      6   380  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
#
#              Valor Moneda      Precio  ...  BARES_DISCO  RUIDO  \
# ...

# %%
datos_ml.shape
# Out:
# (9318, 26)

# %%
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9318 entries, 0 to 9317
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9318 non-null   object
#  1   Descripcion               9318 non-null   object
#  2   Habitaciones              9318 non-null   int64
#  3   Banos                     9318 non-null   int64
#  4   Area                      9318 non-null   int64
#  5   Barrio                    9318 non-null   object
#  6   UPZ                       9318 non-null   object
#  7   Valor                     9318 non-null   object
#  8   Moneda                    9318 non-null   object
#  9   Precio                    9318 non-null   object
#  10  Precio_Millon             9318 non-null   float64
#  11  valor_metroCuadrado       9318 non-null   float64
#  12  valor_m2_Barrio           9318 non-null   float64
# ...

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml,y='Precio_Millon')
plt.show()

# %%
datos_ml.query('Precio_Millon > 5000 | Precio_Millon < 60')
# Out:
#                      Tipo                                  Descripcion  \
# 207           Apartamento            Apartamento en venta en Chapinero
# 323                 Local                  Local en venta en Chapinero
# 702                  Casa                   Casa en venta en Chapinero
# 708                  Casa                   Casa en venta en Chapinero
# 829           Apartamento   Apartamento en venta en Zona Noroccidental
# 1371          Apartamento             Apartamento en venta en El Chicó
# 1414          Apartamento             Apartamento en venta en El Chicó
# 1429                Local             Local en venta en Quinta Camacho
# 1442                Local             Local en venta en Quinta Camacho
# 1518          Apartamento      Apartamento en venta en Chico Reservado
# 1532          Apartamento          Apartamento en venta en Chico Norte
# 1533          Apartamento          Apartamento en venta en Los Rosales
# ...

# %%
datos_ml = datos_ml.query('Precio_Millon < 1200 & Precio_Millon > 60')
datos_ml
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 0     Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1            Casa                      Casa en venta en Marly             3
# 3     Apartamento  Apartamento en venta en Zona Noroccidental             2
# 9            Casa         Casa en venta en Zona Noroccidental             5
# 10    Apartamento  Apartamento en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 9313  Apartamento            Apartamento en venta en Verbenal             2
# 9314  Apartamento            Apartamento en venta en Verbenal             2
# 9315  Apartamento            Apartamento en venta en Verbenal             2
# 9316  Apartamento            Apartamento en venta en Verbenal             2
# 9317  Apartamento            Apartamento en venta en Verbenal             2
#
# ...

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml,y='Precio_Millon')
plt.show()

# %%
datos_ml['SALARIO_ANUAL_MI'] = datos_ml['SALARIO_MES']*12/1000000
datos_ml['SALARIO_ANUAL_MI']
# Out:
# <ipython-input-168-71287e70a4cf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_ml['SALARIO_ANUAL_MI'] = datos_ml['SALARIO_MES']*12/1000000
# 0      48.42
# 1      48.42
# 3      48.42
# 9      48.42
# 10     48.42
#         ...
# 9313   29.34
# 9314   29.34
# 9315   29.34
# 9316   29.34
# 9317   29.34
# Name: SALARIO_ANUAL_MI, Length: 8313, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml,x='SALARIO_ANUAL_MI',y='valor_metroCuadrado')
#plt.ylim((0,15))
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml,x='SALARIO_ANUAL_MI',y='valor_metroCuadrado')
plt.ylim((0,15))
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=datos_ml,x='SALARIO_ANUAL_MI',y='valor_metroCuadrado')
#plt.ylim((0,15))
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=datos_ml,x='SALARIO_ANUAL_MI',y='valor_metroCuadrado')
plt.ylim((0,15))
plt.show()

# %%
datos_ml.corr()
# Out:
#                           Habitaciones  Banos  Area  Precio_Millon  \
# Habitaciones                      1.00   0.44  0.03           0.18
# Banos                             0.44   1.00  0.04           0.66
# Area                              0.03   0.04  1.00           0.04
# Precio_Millon                     0.18   0.66  0.04           1.00
# valor_metroCuadrado              -0.31  -0.03 -0.04           0.36
# valor_m2_Barrio                  -0.21   0.13 -0.04           0.40
# CONJUNTO_CERRADO                 -0.12   0.16 -0.01           0.32
# INSEGURIDAD                       0.13  -0.19 -0.00          -0.37
# TERMINALES_BUS                    0.08  -0.17 -0.01          -0.28
# BARES_DISCO                       0.11  -0.12 -0.01          -0.23
# RUIDO                             0.14  -0.17 -0.00          -0.35
# OSCURO_PELIGROSO                  0.11  -0.21  0.01          -0.38
# SALARIO_MES                      -0.17   0.18 -0.01           0.42
# ...

# %%
plt.figure(figsize=(18, 8))
#https://www.tylervigen.com/spurious-correlations
#mascara = np.triu(np.ones_like(datos_ml.corr(), dtype=bool)) mask=mascara,
heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlación de las variables', fontdict={'fontsize':18}, pad=16);

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = datos_ml[['COD_UPZ_GRUPO']]
y = datos_ml['Precio_Millon']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=99)

# %%
X_train
# Out:
#       COD_UPZ_GRUPO  Habitaciones  Banos
# 7578         810.00            11      6
# 8345          98.00             8      6
# 1246         816.00             2      2
# 8491         809.00             3      2
# 4602          47.00             4      2
# ...             ...           ...    ...
# 5223          19.00             3      2
# 7929          85.00             2      1
# 1784         817.00             3      3
# 3268          14.00             3      2
# 7242          20.00             2      2
#
# [6957 rows x 3 columns]

# %%
X_test
# Out:
#       COD_UPZ_GRUPO  Habitaciones  Banos
# 8428         809.00             5      3
# 3079          14.00             2      2
# 6927          75.00             3      2
# 6861          75.00             2      2
# 2357          14.00             3      3
# ...             ...           ...    ...
# 7777          85.00             3      1
# 1423         817.00             3      4
# 3916         803.00             3      3
# 8305          98.00             6      3
# 3989         803.00             1      1
#
# [2320 rows x 3 columns]

# %%
y_train
# Out:
# 7578   550.00
# 8345   700.00
# 1246   710.00
# 8491   400.00
# 4602   650.00
#         ...
# 5223   360.00
# 7929   119.00
# 1784   650.00
# 3268   350.00
# 7242   480.00
# Name: Precio_Millon, Length: 6957, dtype: float64

# %%
y_test
# Out:
# 8428    650.00
# 3079    550.00
# 6927    327.00
# 6861    260.00
# 2357    460.00
#          ...
# 7777    131.00
# 1423    695.00
# 3916   1000.00
# 8305   1100.00
# 3989    265.00
# Name: Precio_Millon, Length: 2320, dtype: float64

# %%
modelo = LinearRegression()

# %%
modelo.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict_test = modelo.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

baseline_mae = mean_absolute_error(y_test, y_predict_test)
baseline_r2 = r2_score(y_test,y_predict_test)
print(baseline_mae,baseline_r2)
# Out:
# 187.323609443345 0.031111799984413713

# %%
X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Banos','CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA']] #,'CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA'

Y = datos_ml["Precio_Millon"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 118.25967274431333 0.5404735562069192
# 123.22271988681676 0.5269614226488988

# %% [markdown]
# **CONCLUSIONES:** en la primera linea(datos de prueba) evidenciamos que tuevieron un mejor desempeño que la segunda linea (datos de entrenamiento) a la hora de validar el modelo, **NOTA:** se evidencia que nuestro modelo esta mejorando

# %% [markdown]
# probamos el modelo dando le datos "reales"

# %%
modelo_1.predict([[816,3,2,1,50,1]])
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([434.21129691])
